# %%
import pandas 
from pandas import DataFrame
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('3.2 cost_revenue_clean .csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data , columns=['production_budget_usd'])
y = DataFrame(data , columns=['worldwide_gross_usd'])

# %%
# Step 4: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train) 
print(y_train)
# Out:
#       production_budget_usd
# 2088               17000000
# 3151               35000000
# 3933              150000000
# 3595               15500000
# 4370               75000000
# ...                     ...
# 1843                6800000
# 488                 1000000
# 2660               72000000
# 3054               20000000
# 1295               16000000
#
# [4027 rows x 1 columns]
#       worldwide_gross_usd
# 2088             21170563
# 3151             58405313
# 3933            123888320
# 3595             88611837
# 4370            203035572
# ...                   ...
# 1843             16038343
# 488                475367
# 2660             37306334
# 3054             53976987
# 1295              7585011
#
# [4027 rows x 1 columns]

# %%
regression = LinearRegression()
regression.fit(X_train,y_train )
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[3.1441491]])

# %%
regression.intercept_
# Out:
# array([-7372779.42486697])

# %%
#plt.figure(figsize=(10,6))
plt.scatter(X,y,alpha=0.3)
plt.plot(X, regression.predict(X), color='red', linewidth=3)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Movie Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
regression.score(X,y)
# Out:
# 0.5495585421040424

# %%
import numpy as np
X_new = np.array([[1246738426],[738364524237]])
p1 = regression.predict(X_new)
p1
# Out:
# C:\Users\shyam\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.91255873e+09],
#        [2.32152078e+12]])
