# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('figure', figsize=(10, 8))
plt.style.use('fivethirtyeight')

# %%
import matplotlib.pyplot as plt

# Sample data: scores of students
scores = [55, 60, 65, 70, 70, 75, 80, 85, 85, 90, 90, 90, 95, 100]

# Plot histogram
plt.hist(scores, bins=5, color='red',edgecolor='green')

# Add titles and labels
plt.title("Histogram of Student Scores")
plt.xlabel("Score")
plt.ylabel("Number of Students")

plt.show()
